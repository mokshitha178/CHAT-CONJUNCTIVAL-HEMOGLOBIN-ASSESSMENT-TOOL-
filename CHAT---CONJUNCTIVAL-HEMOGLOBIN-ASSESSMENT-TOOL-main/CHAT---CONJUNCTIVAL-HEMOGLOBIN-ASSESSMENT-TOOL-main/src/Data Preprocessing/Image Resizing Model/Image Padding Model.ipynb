# %% [markdown]
# #model 1

# %%
import cv2
import os
import numpy as np

# Fixed size for all images
TARGET_SIZE = (224, 224)

def resize_with_padding(img, size=TARGET_SIZE):
    h, w = img.shape[:2]
    scale = min(size[0] / w, size[1] / h)  # Scale factor to fit in target size
    new_w, new_h = int(w * scale), int(h * scale)

    # Resize while maintaining aspect ratio
    resized_img = cv2.resize(img, (new_w, new_h), interpolation=cv2.INTER_AREA)

    # Create a blank image (black background)
    pad_x = (size[0] - new_w) // 2
    pad_y = (size[1] - new_h) // 2
    padded_img = np.zeros((size[1], size[0], 3), dtype=np.uint8)  # Black padding

    # Place the resized image in the center
    padded_img[pad_y:pad_y+new_h, pad_x:pad_x+new_w] = resized_img
    return padded_img

# Function to detect and crop conjunctiva
def detect_and_crop_conjunctiva(img):
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    _, thresh = cv2.threshold(gray, 10, 255, cv2.THRESH_BINARY)

    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if contours:
        largest_contour = max(contours, key=cv2.contourArea)
        x, y, w, h = cv2.boundingRect(largest_contour)
        return img[y:y+h, x:x+w]
    return None

# Process images and save resized versions in respective folders
def process_images(input_folder, output_folder):
    for root, _, files in os.walk(input_folder):
        for file in files:
            if file.lower().endswith(('.jpg', '.png', '.jpeg')):
                img_path = os.path.join(root, file)
                img = cv2.imread(img_path)

                if img is not None:
                    cropped_conjunctiva = detect_and_crop_conjunctiva(img)
                    if cropped_conjunctiva is not None:
                        resized_img = resize_with_padding(cropped_conjunctiva)  # Resize to fixed size

                        # Preserve folder structure
                        relative_path = os.path.relpath(root, input_folder)
                        save_dir = os.path.join(output_folder, relative_path)
                        os.makedirs(save_dir, exist_ok=True)

                        # Save image with original filename
                        save_path = os.path.join(save_dir, file)
                        cv2.imwrite(save_path, resized_img)
                        print(f"Processed and saved: {save_path}")

# Define input/output folders
input_folder = "Raw_Images_Folder"
output_folder = "Image_Padding_Folder"

# Process images
process_images(input_folder, output_folder)
# Out:
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_33_0_8416.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_31_0_9181.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_30_0_3562.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_29_0_4429.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_32_0_877.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_0_0_6529.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./1687331563189.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_3_0_9915.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_1_0_453.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_4_0_1674.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_12_0_5013.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_66_0_6057.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_64_0_1220.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_65_0_3080.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_69_0_4060.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_67_0_8996.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_63_0_6433.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_68_0_4553.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_85_0_9388.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_49_0_2143.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_47_0_1833.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_46_0_4037.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_48_0_3305.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_70_0_6864.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_2_0_9836.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_81_0_8563.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_78_0_5320.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_84_0_4891.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_86_0_4386.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_80_0_8340.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_82_0_350.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_83_0_1385.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_79_0_6132.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_51_0_3935.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_58_0_4185.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_50_0_5045.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_19_0_601.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_17_0_782.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_18_0_1345.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_16_0_5518.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_14_0_7038.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_15_0_2453.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_44_0_6688.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_10_0_4486.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_13_0_3420.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_54_0_7707.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_52_0_3039.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_56_0_9262.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_55_0_4946.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_53_0_92.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./1731135077896.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./1687153715416.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_61_0_4730.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_60_0_8358.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_59_0_5700.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_62_0_5946.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_72_0_3705.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_34_0_9701.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_71_0_8999.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_20_0_579.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_22_0_6414.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_23_0_2931.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_21_0_4587.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_24_0_6890.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_57_0_8239.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./1687153704736.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_45_0_4908.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_38_0_9655.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./1684219703477.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./1684219712273.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./1730960271892.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./1730957446809.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./1731135071303.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./1730960282407.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_25_0_366.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_28_0_3882.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_26_0_5497.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_42_0_8501.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_6_0_1579.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_11_0_3571.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_8_0_5003.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_9_0_3507.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_7_0_4656.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_5_0_4426.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_40_0_3199.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_39_0_2515.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_43_0_7678.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_36_0_3686.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_41_0_1321.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_37_0_2146.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_35_0_7962.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_27_0_9174.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_89_0_3185.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_88_0_3590.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_87_0_8765.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_75_0_1444.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_77_0_8745.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_74_0_759.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_73_0_2492.jpg
# Processed and saved: /content/drive/MyDrive/master folder/eye resizing folder/./Severe Anemia_aug_76_0_5100.jpg

# %%
import os
import cv2

def check_image_sizes(folder_path):
    for root, _, files in os.walk(folder_path):
        for file in files:
            if file.lower().endswith(('.jpg', '.jpeg', '.png')):
                img_path = os.path.join(root, file)
                img = cv2.imread(img_path)

                if img is not None:
                    h, w = img.shape[:2]
                    print(f"{file}: {w}x{h} pixels")

# Set the folder path
folder_path = "/content/drive/MyDrive/master folder/eye resizing folder"

# Check image sizes
check_image_sizes(folder_path)
# Out:
# Severe Anemia_aug_33_0_8416.jpg: 224x224 pixels
# Severe Anemia_aug_31_0_9181.jpg: 224x224 pixels
# Severe Anemia_aug_30_0_3562.jpg: 224x224 pixels
# Severe Anemia_aug_29_0_4429.jpg: 224x224 pixels
# Severe Anemia_aug_32_0_877.jpg: 224x224 pixels
# Severe Anemia_aug_0_0_6529.jpg: 224x224 pixels
# 1687331563189.jpg: 224x224 pixels
# Severe Anemia_aug_3_0_9915.jpg: 224x224 pixels
# Severe Anemia_aug_1_0_453.jpg: 224x224 pixels
# Severe Anemia_aug_4_0_1674.jpg: 224x224 pixels
# Severe Anemia_aug_12_0_5013.jpg: 224x224 pixels
# Severe Anemia_aug_66_0_6057.jpg: 224x224 pixels
# Severe Anemia_aug_64_0_1220.jpg: 224x224 pixels
# Severe Anemia_aug_65_0_3080.jpg: 224x224 pixels
# Severe Anemia_aug_69_0_4060.jpg: 224x224 pixels
# Severe Anemia_aug_67_0_8996.jpg: 224x224 pixels
# Severe Anemia_aug_63_0_6433.jpg: 224x224 pixels
# Severe Anemia_aug_68_0_4553.jpg: 224x224 pixels
# Severe Anemia_aug_85_0_9388.jpg: 224x224 pixels
# Severe Anemia_aug_49_0_2143.jpg: 224x224 pixels
# Severe Anemia_aug_47_0_1833.jpg: 224x224 pixels
# Severe Anemia_aug_46_0_4037.jpg: 224x224 pixels
# Severe Anemia_aug_48_0_3305.jpg: 224x224 pixels
# Severe Anemia_aug_70_0_6864.jpg: 224x224 pixels
# Severe Anemia_aug_2_0_9836.jpg: 224x224 pixels
# Severe Anemia_aug_81_0_8563.jpg: 224x224 pixels
# Severe Anemia_aug_78_0_5320.jpg: 224x224 pixels
# Severe Anemia_aug_28_0_3882.jpg: 224x224 pixels
# Severe Anemia_aug_26_0_5497.jpg: 224x224 pixels
# Severe Anemia_aug_42_0_8501.jpg: 224x224 pixels
# Severe Anemia_aug_6_0_1579.jpg: 224x224 pixels
# Severe Anemia_aug_11_0_3571.jpg: 224x224 pixels
# Severe Anemia_aug_8_0_5003.jpg: 224x224 pixels
# Severe Anemia_aug_9_0_3507.jpg: 224x224 pixels
# Severe Anemia_aug_7_0_4656.jpg: 224x224 pixels
# Severe Anemia_aug_5_0_4426.jpg: 224x224 pixels
# Severe Anemia_aug_40_0_3199.jpg: 224x224 pixels
# Severe Anemia_aug_39_0_2515.jpg: 224x224 pixels
# Severe Anemia_aug_43_0_7678.jpg: 224x224 pixels
# Severe Anemia_aug_36_0_3686.jpg: 224x224 pixels
# Severe Anemia_aug_41_0_1321.jpg: 224x224 pixels
# Severe Anemia_aug_37_0_2146.jpg: 224x224 pixels
# Severe Anemia_aug_35_0_7962.jpg: 224x224 pixels
# Severe Anemia_aug_27_0_9174.jpg: 224x224 pixels
# Severe Anemia_aug_89_0_3185.jpg: 224x224 pixels
# Severe Anemia_aug_88_0_3590.jpg: 224x224 pixels
# Severe Anemia_aug_87_0_8765.jpg: 224x224 pixels
# Severe Anemia_aug_75_0_1444.jpg: 224x224 pixels
# Severe Anemia_aug_77_0_8745.jpg: 224x224 pixels
# Severe Anemia_aug_74_0_759.jpg: 224x224 pixels
# Severe Anemia_aug_73_0_2492.jpg: 224x224 pixels
# Severe Anemia_aug_76_0_5100.jpg: 224x224 pixels

# %%
import os
import cv2
import matplotlib.pyplot as plt

# Define target size
TARGET_WIDTH = 256
TARGET_HEIGHT = 256

def process_images(folder_path):
    for root, _, files in os.walk(folder_path):
        for file in files:
            if file.lower().endswith(('.jpg', '.jpeg', '.png')):
                img_path = os.path.join(root, file)
                img = cv2.imread(img_path)

                if img is not None:
                    h, w = img.shape[:2]
                    print(f"Before: {file} - {w}x{h} pixels")

                    # Resize the image
                    resized_img = cv2.resize(img, (TARGET_WIDTH, TARGET_HEIGHT))

                    # Display original vs resized image
                    fig, ax = plt.subplots(1, 2, figsize=(8, 4))

                    ax[0].imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
                    ax[0].set_title(f"Original ({w}x{h})")
                    ax[0].axis("off")

                    ax[1].imshow(cv2.cvtColor(resized_img, cv2.COLOR_BGR2RGB))
                    ax[1].set_title(f"Resized ({TARGET_WIDTH}x{TARGET_HEIGHT})")
                    ax[1].axis("off")

                    plt.show()

                    # Save the resized image in the same location
                    cv2.imwrite(img_path, resized_img)

                    print(f"After: {file} - {TARGET_WIDTH}x{TARGET_HEIGHT} pixels\n")

# Set the folder path
folder_path = "/content/drive/MyDrive/master folder/eye resizing folder"

# Process images
process_images(folder_path)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# #model 2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import os
import numpy as np

# Define target size (Set to desired width, height)
TARGET_SIZE = (224, 224)  # Example: 256x256, change as needed

# Function to resize images while maintaining aspect ratio and padding with black
def resize_with_padding(img, size=TARGET_SIZE):
    h, w = img.shape[:2]
    scale = min(size[0] / w, size[1] / h)  # Scale factor to fit in target size
    new_w, new_h = int(w * scale), int(h * scale)

    # Resize while maintaining aspect ratio
    resized_img = cv2.resize(img, (new_w, new_h), interpolation=cv2.INTER_AREA)

    # Create a blank black image
    pad_x = (size[0] - new_w) // 2
    pad_y = (size[1] - new_h) // 2
    padded_img = np.zeros((size[1], size[0], 3), dtype=np.uint8)  # Black background

    # Place the resized image in the center
    padded_img[pad_y:pad_y+new_h, pad_x:pad_x+new_w] = resized_img
    return padded_img

# Function to process all images in folders
def process_images(input_folder, output_folder):
    for root, _, files in os.walk(input_folder):
        for file in files:
            if file.lower().endswith((".jpg", ".jpeg", ".png")):  # Only process image files
                img_path = os.path.join(root, file)
                img = cv2.imread(img_path)

                if img is not None:
                    # Resize and pad image
                    processed_img = resize_with_padding(img)

                    # Create output directory structure
                    relative_path = os.path.relpath(root, input_folder)  # Get subfolder structure
                    save_dir = os.path.join(output_folder, relative_path)
                    os.makedirs(save_dir, exist_ok=True)  # Create folder if not exists

                    # Save image with original name
                    save_path = os.path.join(save_dir, file)
                    cv2.imwrite(save_path, processed_img)
                    print(f"Saved: {save_path}")

# Set paths (Modify these paths as needed)
input_folder = "/content/drive/MyDrive/master folder/balanced data set(cropped)3"
output_folder = "/content/drive/MyDrive/master folder/balanced data set (resized)"

# Run processing
process_images(input_folder, output_folder)
# Out:
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/1731135124261.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/1731135131624.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/1683518279079.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/1683518265539.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/1687498742041.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/1687498756863.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/1731134292707.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/1731133398081.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/1731133408723.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/1688796903747.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/1730961077716.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/IMG_2132-8_4_58.jpeg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/IMG_2131-8_4_51.jpeg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/1686903943553.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/1686903951815.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/1730962677228.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/1730962684942.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/1730957161015.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/1730957149052.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/1683780425723.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/1683780410365.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/1688099934479.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/1686984287242.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/1731135220203.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_0_0_2195.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_1_0_8366.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_2_0_6352.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_3_0_9269.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_4_0_1726.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_5_0_6737.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_6_0_7636.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_7_0_990.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_8_0_9252.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_9_0_5227.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_10_0_266.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_11_0_8626.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_12_0_949.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_13_0_818.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_14_0_3275.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_15_0_7874.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_16_0_9541.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_17_0_9410.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_18_0_8794.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_19_0_9472.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_20_0_6791.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_21_0_3245.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_22_0_9213.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_23_0_9189.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_24_0_6865.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_25_0_234.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_26_0_6172.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_27_0_2294.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_28_0_7212.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_29_0_696.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_30_0_7706.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_31_0_8292.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_32_0_6881.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_33_0_4518.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_34_0_6207.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_35_0_1140.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_36_0_5180.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_37_0_1887.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_38_0_5355.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_39_0_9187.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_40_0_7082.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_41_0_2681.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_42_0_8875.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_43_0_5646.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_44_0_513.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_45_0_2421.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_46_0_1606.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_47_0_5587.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_48_0_4796.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_49_0_4974.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_50_0_1384.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_51_0_6634.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_52_0_7162.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_53_0_3635.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_54_0_8607.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_55_0_3407.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_56_0_7084.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_57_0_4213.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_58_0_8716.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_59_0_471.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_60_0_9947.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_61_0_9133.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_62_0_2502.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug_63_0_5504.jpg
# Saved: /content/drive/MyDrive/master folder/balanced data set (resized)/Mild Anemia/Mild Anemia_aug